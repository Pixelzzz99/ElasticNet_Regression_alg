# %%
import numpy as np 
import pandas as pd
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt  
from sklearn import preprocessing
import task03_JavlievSA_model as EN

# %%
import task03_JavlievSA_tests as mytests

# %%
tests = mytests.ElasticNetRegressorsTester

# %%
test1_result = tests.test1_boston_test()
# Out:
# X Shape:  (506, 13)
# Y Shape:  (506,)
# X_Train Shape:  (354, 13)
# X_Test Shape:  (152, 13)
# Y_Train Shape:  (354,)
# Y_Test Shape:  (152,)
# Find best score with best values
# Best alpha:  0.1
# Best l1 value:  33
# Best l2 value:  2
# Best score with this values:  0.6168038389322588
# My score in relation to tests:  0.6168038389322588
# Sklearn score in relation to tests:  0.6466393192632923
# My score in relation to result sklearn:  0.9657993360736041

# %%
test2_result = tests.test2_diabetes_test()
# Out:
# X Shape:  (442, 10)
# Y Shape:  (442,)
# X_Train Shape:  (309, 10)
# X_Test Shape:  (133, 10)
# Y_Train Shape:  (309,)
# Y_Test Shape:  (133,)
# Find best score with best values
# Best alpha:  0.1
# Best l1 value:  20
# Best l2 value:  1
# Best score with this values:  0.4604483343703256
# My score in relation to tests:  0.4604483343703256
# Sklearn score in relation to tests:  0.45524141067900736
# My score in relation to result sklearn:  0.7714153458749806

# %%
test3_result = tests.test3_iris_test()
# Out:
# X Shape:  (150, 4)
# Y Shape:  (150,)
# X_Train Shape:  (105, 4)
# X_Test Shape:  (45, 4)
# Y_Train Shape:  (105,)
# Y_Test Shape:  (45,)
# Find best score with best values
# Best alpha:  0.1
# Best l1 value:  22
# Best l2 value:  9
# Best score with this values:  0.8295390989569116
# My score in relation to tests:  0.8295390989569116
# Sklearn score in relation to tests:  0.3750860434401181
# My score in relation to result sklearn:  -11.679616206415885

# %%
test4_result = tests.test4_digits_test()
# Out:
# X Shape:  (1797, 64)
# Y Shape:  (1797,)
# X_Train Shape:  (1257, 64)
# X_Test Shape:  (540, 64)
# Y_Train Shape:  (1257,)
# Y_Test Shape:  (540,)
# Find best score with best values
# Best alpha:  0.01
# Best l1 value:  55
# Best l2 value:  9
# Best score with this values:  0.055347340657955435
# My score in relation to tests:  0.055347340657955435
# Sklearn score in relation to tests:  0.1808540955462501
# My score in relation to result sklearn:  -0.7993188173277048
